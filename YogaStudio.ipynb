# %% [markdown]
# # Yoga Studio Optimal Location Finder

# %%
import numpy as np
import csv
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
import requests # library to handle requests
from pandas.io.json import json_normalize
import folium
print('Finished Importing Packages')
# Out:
# Finished Importing Packages

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv(r"E:\Downloads E\chic_coords.csv")
df.head()
# Out:
#      Zip           City State  Latitude  Longitude
# 0  46312   East Chicago    IN    41.640    -87.461
# 1  60064  North Chicago    IL    42.326    -87.852
# 2  60086  North Chicago    IL    42.433    -87.777
# 3  60185   West Chicago    IL    41.892    -88.205
# 4  60186   West Chicago    IL    41.840    -88.089

# %% [markdown]
# ### Only Select Neighbourhoods from Chicago Proper

# %%
df = df[df.City == 'Chicago']
df.drop(['City', 'State'], axis = 1)
city_areas = df[['Zip', 'Latitude', 'Longitude']]
city_areas.head()
# Out:
#       Zip  Latitude  Longitude
# 8   60601    41.886    -87.623
# 9   60602    41.883    -87.629
# 10  60603    41.880    -87.630
# 11  60604    41.878    -87.628
# 12  60605    41.860    -87.619

# %% [markdown]
# ### Visualize City Areas

# %%
city_map = folium.Map(location=[41.882, -87.645], zoom_start=10)
for lat, lng, zipcode in zip(city_areas['Latitude'], city_areas['Longitude'], city_areas['Zip']):
    label = '{}'.format(zipcode)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(city_map)
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Obtain Foursquare Location Data

# %%
CLIENT_ID = 'X55WKRFHFORIEZCWGAXX0ABI2RO5HXD0E5NQCBVAMQFRGIQD' # your Foursquare ID
CLIENT_SECRET = '1FHGN5CRA2X4SN2SG0K1G43QL33Z34L3VHZUQDGGNH1UMT5M' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
def getNearbyVenues(postcode, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for postcode, lat, lng in zip(postcode, latitudes, longitudes):
        
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            postcode, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Zip', 
                  'Latitude', 
                  'Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
city_venues = getNearbyVenues(postcode=city_areas['Zip'],
                                   latitudes=city_areas['Latitude'],
                                   longitudes=city_areas['Longitude']
                                  )
print(city_venues.shape)
city_venues.head()
# Out:
# (1902, 7)
#      Zip  Latitude  Longitude                        Venue  Venue Latitude  \
# 0  60601    41.886    -87.623                   sweetgreen       41.884964
# 1  60601    41.886    -87.623  Chicago Architecture Center       41.887720
# 2  60601    41.886    -87.623    Roti Modern Mediterranean       41.886048
# 3  60601    41.886    -87.623    Wildberry Pancakes & Cafe       41.884412
# 4  60601    41.886    -87.623             St. Jane Chicago       41.886573
#
#    Venue Longitude            Venue Category
# 0       -87.624728               Salad Place
# 1       -87.623650             Tour Provider
# 2       -87.624948  Mediterranean Restaurant
# 3       -87.623047            Breakfast Spot
# 4       -87.624902                     Hotel

# %%
city_venues.groupby('Zip').count().head()
# Out:
#        Latitude  Longitude  Venue  Venue Latitude  Venue Longitude  \
# Zip
# 60601       100        100    100             100              100
# 60602       100        100    100             100              100
# 60603       100        100    100             100              100
# 60604       100        100    100             100              100
# 60605        21         21     21              21               21
#
#        Venue Category
# Zip
# 60601             100
# 60602             100
# 60603             100
# 60604             100
# 60605              21

# %%
print('There are {} unique venue categories.'.format(len(city_venues['Venue Category'].unique())))
# Out:
# There are 250 unique venue categories.

# %%
# one hot encoding
city_onehot = pd.get_dummies(city_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
city_onehot['Zip'] = city_venues['Zip'] 

# move neighborhood column to the first column
fixed_columns = [city_onehot.columns[-1]] + list(city_onehot.columns[:-1])
city_onehot = city_onehot[fixed_columns]

# %%
city_grouped = city_onehot.groupby('Zip').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Zip']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Zip'] = city_grouped['Zip']

for ind in np.arange(city_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(city_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#      Zip 1st Most Common Venue 2nd Most Common Venue  \
# 0  60601                 Hotel           Coffee Shop
# 1  60602           Coffee Shop                 Hotel
# 2  60603           Coffee Shop                 Hotel
# 3  60604           Coffee Shop        Sandwich Place
# 4  60605      Football Stadium         Historic Site
#
#        3rd Most Common Venue 4th Most Common Venue     5th Most Common Venue  \
# 0         Seafood Restaurant                 Plaza       American Restaurant
# 1                    Theater   American Restaurant  Mediterranean Restaurant
# 2  Middle Eastern Restaurant           Salad Place       American Restaurant
# 3                      Hotel    Italian Restaurant                   Theater
# 4                       Park   Sporting Goods Shop                    Museum
#
#            6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                           Park            Steakhouse                Bakery
# 1                      Gastropub    Italian Restaurant           Snack Place
# 2  Vegetarian / Vegan Restaurant               Theater      Asian Restaurant
# 3               Asian Restaurant                  Café            Smoke Shop
# 4                   Burger Joint                Bistro    English Restaurant
#
#      9th Most Common Venue 10th Most Common Venue
# 0                  Theater                    Bar
# 1  New American Restaurant                    Bar
# 2             Dessert Shop                 Museum
# 3              Snack Place            Salad Place
# 4         Sushi Restaurant                    Bar

# %% [markdown]
# ### Cluster neighbourhoods by common venues

# %%
# set number of clusters
kclusters = 5

city_grouped_clustering = city_grouped.drop('Zip', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(city_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 3, 4, 1])

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

city_merged = city_areas


city_merged = city_merged.join(neighborhoods_venues_sorted.set_index('Zip'), on='Zip')

city_merged.head()
# Out:
#       Zip  Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 8   60601    41.886    -87.623               1                 Hotel
# 9   60602    41.883    -87.629               1           Coffee Shop
# 10  60603    41.880    -87.630               1           Coffee Shop
# 11  60604    41.878    -87.628               1           Coffee Shop
# 12  60605    41.860    -87.619               1      Football Stadium
#
#    2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 8            Coffee Shop         Seafood Restaurant                 Plaza
# 9                  Hotel                    Theater   American Restaurant
# 10                 Hotel  Middle Eastern Restaurant           Salad Place
# 11        Sandwich Place                      Hotel    Italian Restaurant
# 12         Historic Site                       Park   Sporting Goods Shop
#
#        5th Most Common Venue          6th Most Common Venue  \
# 8        American Restaurant                           Park
# 9   Mediterranean Restaurant                      Gastropub
# 10       American Restaurant  Vegetarian / Vegan Restaurant
# 11                   Theater               Asian Restaurant
# 12                    Museum                   Burger Joint
#
#    7th Most Common Venue 8th Most Common Venue    9th Most Common Venue  \
# 8             Steakhouse                Bakery                  Theater
# 9     Italian Restaurant           Snack Place  New American Restaurant
# 10               Theater      Asian Restaurant             Dessert Shop
# 11                  Café            Smoke Shop              Snack Place
# 12                Bistro    English Restaurant         Sushi Restaurant
#
#    10th Most Common Venue
# 8                     Bar
# 9                     Bar
# 10                 Museum
# 11            Salad Place
# 12                    Bar

# %%
latitude = 41.882
longitude = -87.645
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(city_merged['Latitude'], city_merged['Longitude'], city_merged['Zip'], city_merged['Cluster Labels']):
    if np.isnan(cluster):
        cluster = 0
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
city_merged.loc[city_merged['Cluster Labels'] == 0, city_merged.columns[[0] + list(range(4, city_merged.shape[1]))]].head()
# Out:
#       Zip 1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 64  60663     Convenience Store        Ice Cream Shop              Pharmacy
# 65  60664     Convenience Store        Ice Cream Shop              Pharmacy
# 66  60665     Convenience Store        Ice Cream Shop              Pharmacy
# 67  60667     Convenience Store        Ice Cream Shop              Pharmacy
# 68  60668     Convenience Store        Ice Cream Shop              Pharmacy
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 64                Lounge    Mexican Restaurant                  Bank
# 65                Lounge    Mexican Restaurant                  Bank
# 66                Lounge    Mexican Restaurant                  Bank
# 67                Lounge    Mexican Restaurant                  Bank
# 68                Lounge    Mexican Restaurant                  Bank
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 64    Italian Restaurant   Rental Car Location   Arts & Crafts Store
# 65    Italian Restaurant   Rental Car Location   Arts & Crafts Store
# 66    Italian Restaurant   Rental Car Location   Arts & Crafts Store
# 67    Italian Restaurant   Rental Car Location   Arts & Crafts Store
# 68    Italian Restaurant   Rental Car Location   Arts & Crafts Store
#
#     10th Most Common Venue
# 64  Thrift / Vintage Store
# 65  Thrift / Vintage Store
# 66  Thrift / Vintage Store
# 67  Thrift / Vintage Store
# 68  Thrift / Vintage Store

# %%
city_merged.loc[city_merged['Cluster Labels'] == 1, city_merged.columns[[0] + list(range(4, city_merged.shape[1]))]]
# Out:
#       Zip  1st Most Common Venue    2nd Most Common Venue  \
# 8   60601                  Hotel              Coffee Shop
# 9   60602            Coffee Shop                    Hotel
# 10  60603            Coffee Shop                    Hotel
# 11  60604            Coffee Shop           Sandwich Place
# 12  60605       Football Stadium            Historic Site
# 13  60606            Coffee Shop           Sandwich Place
# 14  60607       Greek Restaurant              Coffee Shop
# 17  60610     Italian Restaurant           Sandwich Place
# 18  60611     Italian Restaurant      American Restaurant
# 19  60612            Gas Station                     Park
# 20  60613         Ice Cream Shop              Pizza Place
# 21  60614            Yoga Studio            Hot Dog Joint
# 22  60615            Bus Station               Playground
# 25  60618            Bus Station        Currency Exchange
# 27  60620      Currency Exchange  Health & Beauty Service
# 28  60621               Pharmacy           Discount Store
# 29  60622     Mexican Restaurant                      Bar
# 31  60624             Shoe Store     Fast Food Restaurant
# 34  60628         Sandwich Place                BBQ Joint
# 36  60630                   Park                      Bar
# 37  60631                    Gym              Coffee Shop
# 38  60632     Seafood Restaurant         Storage Facility
# 40  60634                    Bar                     Park
# 41  60636   Fast Food Restaurant            Train Station
# 42  60637         Cosmetics Shop                     Park
# 43  60638                   Café                      Spa
# 45  60640   Gym / Fitness Center                 Beer Bar
# 48  60644                    ATM                 Pharmacy
# 49  60645  Check Cashing Service                     Park
# 50  60646         Sandwich Place                    Diner
# 52  60649     Seafood Restaurant           Discount Store
# 55  60652             Sports Bar            Train Station
# 56  60653            Coffee Shop                 Boutique
# 57  60654             Steakhouse       Italian Restaurant
# 60  60657  Performing Arts Venue              Coffee Shop
# 62  60660                Theater              Coffee Shop
# 63  60661            Coffee Shop                      Bar
# 87  60692         Sandwich Place               Donut Shop
#
#             3rd Most Common Venue     4th Most Common Venue  \
# 8              Seafood Restaurant                     Plaza
# 9                         Theater       American Restaurant
# 10      Middle Eastern Restaurant               Salad Place
# 11                          Hotel        Italian Restaurant
# 12                           Park       Sporting Goods Shop
# 13        New American Restaurant                Donut Shop
# 14                           Café               Pizza Place
# 17           Gym / Fitness Center                       Gym
# 18                           Café                Steakhouse
# 19             Chinese Restaurant            Sandwich Place
# 20                       Dive Bar   New American Restaurant
# 21                 Sandwich Place                       Bar
# 22                 Baseball Field            Cosmetics Shop
# 25                           Park                      Bank
# 27                         Lounge               Yoga Studio
# 28             Chinese Restaurant            Sandwich Place
# 29                    Coffee Shop         Mobile Phone Shop
# 31           Caribbean Restaurant         Mobile Phone Shop
# 34           Fast Food Restaurant                Steakhouse
# 36                     Art Museum       Filipino Restaurant
# 37                           Bank                      Park
# 38             Italian Restaurant                Donut Shop
# 40                    Gaming Cafe                 Pet Store
# 41                 Cosmetics Shop              Liquor Store
# 42           Fast Food Restaurant      Caribbean Restaurant
# 43                         Bakery                   Dog Run
# 45                            Spa                 Pet Store
# 48                 Discount Store       Fried Chicken Joint
# 49             Salon / Barbershop  Mediterranean Restaurant
# 50                    Golf Course        Italian Restaurant
# 52  Vegetarian / Vegan Restaurant            Sandwich Place
# 55                   Liquor Store               Escape Room
# 56                 Discount Store             Grocery Store
# 57                     Restaurant                     Hotel
# 60                         Bakery                Sports Bar
# 62                          Motel    Furniture / Home Store
# 63        New American Restaurant              Cocktail Bar
# 87                    Coffee Shop             Train Station
#
#        5th Most Common Venue            6th Most Common Venue  \
# 8        American Restaurant                             Park
# 9   Mediterranean Restaurant                        Gastropub
# 10       American Restaurant    Vegetarian / Vegan Restaurant
# 11                   Theater                 Asian Restaurant
# 12                    Museum                     Burger Joint
# 13  Mediterranean Restaurant              American Restaurant
# 14         Convenience Store                   Sandwich Place
# 17                       Bar                      Yoga Studio
# 18               Coffee Shop                              Bar
# 19      Fast Food Restaurant                     Hockey Arena
# 20               Yoga Studio              Sporting Goods Shop
# 21             Grocery Store                      Coffee Shop
# 22                      Park                    Deli / Bodega
# 25                   Theater                              Pub
# 27                   Exhibit      Eastern European Restaurant
# 28                Donut Shop               Seafood Restaurant
# 29            Clothing Store                 Sushi Restaurant
# 31               Supermarket              Fried Chicken Joint
# 34       Fried Chicken Joint               English Restaurant
# 36      Marijuana Dispensary                      Bus Station
# 37                       Spa                             Food
# 38                       Bar           Transportation Service
# 40                  Gym Pool                      Yoga Studio
# 41            Discount Store                             Food
# 42        Salon / Barbershop                            Diner
# 43               Yoga Studio              Filipino Restaurant
# 45              Antique Shop        Middle Eastern Restaurant
# 48        Seafood Restaurant  Southern / Soul Food Restaurant
# 49          Business Service                 Asian Restaurant
# 50                Restaurant                      Gas Station
# 52                Nail Salon               Chinese Restaurant
# 55       Dumpling Restaurant      Eastern European Restaurant
# 56               Gas Station              American Restaurant
# 57            Sandwich Place                              Bar
# 60                      Park                       Taco Place
# 62              Soccer Field                     Intersection
# 63            Sandwich Place                 Sushi Restaurant
# 87        Salon / Barbershop                  Supplement Shop
#
#             7th Most Common Venue            8th Most Common Venue  \
# 8                      Steakhouse                           Bakery
# 9              Italian Restaurant                      Snack Place
# 10                        Theater                 Asian Restaurant
# 11                           Café                       Smoke Shop
# 12                         Bistro               English Restaurant
# 13  Vegetarian / Vegan Restaurant               Falafel Restaurant
# 14                     Sports Bar                              Gym
# 17  Paper / Office Supplies Store                      Coffee Shop
# 18                       Boutique                       Shoe Store
# 19                       Pharmacy                Currency Exchange
# 20                            Bar              Indie Movie Theater
# 21       Bike Rental / Bike Share                        Bookstore
# 22                 Sandwich Place               Seafood Restaurant
# 25                        Brewery                    Shopping Mall
# 27              Electronics Store              Empanada Restaurant
# 28                     Restaurant                      Supermarket
# 29                          Plaza                Korean Restaurant
# 31                 Sandwich Place                   Cosmetics Shop
# 34            Dumpling Restaurant      Eastern European Restaurant
# 36                 Sandwich Place      Eastern European Restaurant
# 37                     Donut Shop             Fast Food Restaurant
# 38                      BBQ Joint               Mexican Restaurant
# 40    Eastern European Restaurant                Electronics Store
# 41                   Dance Studio                Electronics Store
# 42                  Grocery Store                   Discount Store
# 43           Fast Food Restaurant                   Farmers Market
# 45                  Grocery Store                   Sandwich Place
# 48             Falafel Restaurant                          Exhibit
# 49                    Bus Station                     Dessert Shop
# 50                    Bus Station                   Ice Cream Shop
# 52              Mobile Phone Shop                    Deli / Bodega
# 55              Electronics Store              Empanada Restaurant
# 56                 Breakfast Spot  Southern / Soul Food Restaurant
# 57                    Pizza Place         Mediterranean Restaurant
# 60                            Bar               Italian Restaurant
# 62                 Discount Store                            Diner
# 63             Italian Restaurant                    Grocery Store
# 87                    Supermarket               Chinese Restaurant
#
#       9th Most Common Venue 10th Most Common Venue
# 8                   Theater                    Bar
# 9   New American Restaurant                    Bar
# 10             Dessert Shop                 Museum
# 11              Snack Place            Salad Place
# 12         Sushi Restaurant                    Bar
# 13                BBQ Joint                  Hotel
# 14             Dance Studio      Food & Drink Shop
# 17            Deli / Bodega   Fast Food Restaurant
# 18       Salon / Barbershop             Restaurant
# 19               Donut Shop             Sports Bar
# 20              Candy Store                    Spa
# 21                 Building                   Café
# 22               Shoe Store               Fountain
# 25               Shoe Store          Burrito Place
# 27       English Restaurant            Escape Room
# 28                Nightclub          Train Station
# 29       Seafood Restaurant                    Gym
# 31         Department Store           Cycle Studio
# 34        Electronics Store    Empanada Restaurant
# 36      Fried Chicken Joint             Donut Shop
# 37           Farmers Market     Falafel Restaurant
# 38             Home Service     Falafel Restaurant
# 40      Empanada Restaurant     English Restaurant
# 41              Flea Market      Fish & Chips Shop
# 42         Department Store          Deli / Bodega
# 43       Falafel Restaurant                Exhibit
# 45            Indie Theater            Flower Shop
# 48              Escape Room             Donut Shop
# 49                    Diner         Animal Shelter
# 50               Sports Bar           Optical Shop
# 52               Taco Place                 Bakery
# 55       English Restaurant                Exhibit
# 56      Filipino Restaurant   Fast Food Restaurant
# 57       Mexican Restaurant    American Restaurant
# 60      Japanese Restaurant          Bowling Alley
# 62              Bus Station           Dance Studio
# 63         Greek Restaurant             Restaurant
# 87               Food Truck         Ice Cream Shop

# %%
city_merged.loc[city_merged['Cluster Labels'] == 2, city_merged.columns[[0] + list(range(4, city_merged.shape[1]))]]
# Out:
#       Zip 1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 39  60633        Discount Store                Lounge      Greek Restaurant
# 47  60643                  Park          Intersection   American Restaurant
# 53  60650          Intersection               Airport           Yoga Studio
# 88  60693                  Park               Dog Run             Cafeteria
#
#    4th Most Common Venue 5th Most Common Venue        6th Most Common Venue  \
# 39                  Park           Yoga Studio           English Restaurant
# 47                Lounge           Yoga Studio  Eastern European Restaurant
# 53           Escape Room   Dumpling Restaurant  Eastern European Restaurant
# 88              Gym Pool    English Restaurant          Dumpling Restaurant
#
#           7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 39  Eastern European Restaurant     Electronics Store   Empanada Restaurant
# 47            Electronics Store   Empanada Restaurant    English Restaurant
# 53            Electronics Store   Empanada Restaurant    English Restaurant
# 88  Eastern European Restaurant     Electronics Store   Empanada Restaurant
#
#    10th Most Common Venue
# 39            Escape Room
# 47            Escape Room
# 53                Exhibit
# 88            Escape Room

# %%
city_merged.loc[city_merged['Cluster Labels'] == 3, city_merged.columns[[0] + list(range(4, city_merged.shape[1]))]]
# Out:
#       Zip 1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 15  60608           Pizza Place    Mexican Restaurant     Convenience Store
# 23  60616    Chinese Restaurant                  Park      Storage Facility
# 24  60617           Flower Shop                  Park    Mexican Restaurant
# 26  60619            Donut Shop         Train Station           Pizza Place
# 30  60623                Church  Gym / Fitness Center        Discount Store
# 32  60625                  Park                   Gym                  Bank
# 33  60626    Mexican Restaurant   American Restaurant           Pizza Place
# 35  60629           Pizza Place                Bakery    Mexican Restaurant
# 44  60639    Mexican Restaurant            Donut Shop        Ice Cream Shop
# 46  60641     Convenience Store                   Spa    Mexican Restaurant
# 51  60647    Mexican Restaurant          Cocktail Bar     Convenience Store
# 54  60651           Pizza Place           Music Venue                   Spa
# 58  60655                  Park     Convenience Store          Home Service
# 59  60656           Supermarket              Pharmacy                   Pub
# 61  60659    Mexican Restaurant        Breakfast Spot           Video Store
#
#    4th Most Common Venue        5th Most Common Venue 6th Most Common Venue  \
# 15                   Bar                       Bakery        Massage Studio
# 23                Bakery      New American Restaurant           Pizza Place
# 24                   Bar  Eastern European Restaurant     Electronics Store
# 26             BBQ Joint           Mexican Restaurant        Sandwich Place
# 30         Train Station                         Park            Food Truck
# 32        Ice Cream Shop                       Bakery    Mexican Restaurant
# 33      Asian Restaurant                          Bar                Bakery
# 35          Liquor Store                   Laundromat    Italian Restaurant
# 44        Sandwich Place               Discount Store           Bus Station
# 46  Fast Food Restaurant           Chinese Restaurant           Art Gallery
# 51           Pizza Place               Ice Cream Shop           Coffee Shop
# 54         Moving Target                  Flea Market     Currency Exchange
# 58           Pizza Place         Fast Food Restaurant                 Diner
# 59      Asian Restaurant                  Escape Room   Dumpling Restaurant
# 61                 Motel    Middle Eastern Restaurant         Hot Dog Joint
#
#           7th Most Common Venue        8th Most Common Venue  \
# 15              Automotive Shop            Food & Drink Shop
# 23           Seafood Restaurant           Mexican Restaurant
# 24          Empanada Restaurant           English Restaurant
# 26                       Lounge         Caribbean Restaurant
# 30                         Café                  Pizza Place
# 32                 Soccer Field               Farmers Market
# 33           Chinese Restaurant                      Theater
# 35                 Dance Studio                Deli / Bodega
# 44                  Pizza Place                      Exhibit
# 46           English Restaurant  Eastern European Restaurant
# 51                      Brewery               Discount Store
# 54          Dumpling Restaurant         Fast Food Restaurant
# 58                   Donut Shop          Dumpling Restaurant
# 59  Eastern European Restaurant            Electronics Store
# 61               Sandwich Place                   Hookah Bar
#
#           9th Most Common Venue 10th Most Common Venue
# 15                 Dessert Shop         Ice Cream Shop
# 23        Vietnamese Restaurant            Flower Shop
# 24                  Escape Room            Yoga Studio
# 26           Chinese Restaurant                Butcher
# 30                  Escape Room                Exhibit
# 32           Falafel Restaurant                Exhibit
# 33                     Dive Bar         Farmers Market
# 35          Filipino Restaurant               Creperie
# 44                  Escape Room    Dumpling Restaurant
# 46            Electronics Store    Empanada Restaurant
# 51                          Bar                   Café
# 54               Cosmetics Shop         Farmers Market
# 58  Eastern European Restaurant      Electronics Store
# 59          Empanada Restaurant     English Restaurant
# 61                 Liquor Store            Coffee Shop

# %%
city_merged.loc[city_merged['Cluster Labels'] == 4, city_merged.columns[[0] + list(range(4, city_merged.shape[1]))]]
# Out:
#       Zip 1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 16  60609        Shipping Store           Yoga Studio            Donut Shop
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 16   Filipino Restaurant  Fast Food Restaurant        Farmers Market
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 16    Falafel Restaurant               Exhibit           Escape Room
#
#    10th Most Common Venue
# 16     English Restaurant

# %% [markdown]
# ### Find Suburban Cluster

# %%
cols = ['1st Most Common Venue','2nd Most Common Venue','3rd Most Common Venue']
suburban_clusters = []
suburban_score = 0.25
for i in range(5):
    parks = 0
    temp = city_merged.loc[city_merged['Cluster Labels'] == i, ['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue']]
    rows = len(temp.index)
    for col in cols:
         parks = parks + temp[temp == 'Park'][col].count()
    parks = parks/rows
    if parks>suburban_score:
        suburban_clusters.append(i)
suburban_clusters
# Out:
# [2, 3]

# %%
good_zips = []
cols = ['1st Most Common Venue','2nd Most Common Venue','3rd Most Common Venue', '4th Most Common Venue', '5th Most Common Venue','6th Most Common Venue','7th Most Common Venue','8th Most Common Venue']
for i in suburban_clusters:
    temp = city_merged.loc[city_merged['Cluster Labels'] == i, ['Zip','1st Most Common Venue','2nd Most Common Venue','3rd Most Common Venue', '4th Most Common Venue', '5th Most Common Venue','6th Most Common Venue','7th Most Common Venue','8th Most Common Venue']]
    for index, row in temp.iterrows():
        good = True
        for col in cols:
            if row[col] == 'Yoga Studio':
                good = False
                break
        if good == True:
            good_zips.append(row['Zip'])
print('Ideal zip codes for a new Yoga Studio include:')
for i in good_zips:
    print(i)
# Out:
# Ideal zip codes for a new Yoga Studio include:
# 60693
# 60608
# 60616
# 60617
# 60619
# 60623
# 60625
# 60626
# 60629
# 60639
# 60641
# 60647
# 60651
# 60655
# 60656
# 60659
